# %%
##DEPLOYMENT
## run "https://chitra2445-ml-stream-ma-uzsnz2.streamlit.app/"

# %% [markdown]
# <h1>RANK CONVERTER</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("final_cccf.csv")

# %%
df.shape
# Out:
# (11275, 5)

# %%
df.columns
# Out:
# Index(['ss_username', 'cf_username', 'cf_rating', 'cc_username', 'cc_rating'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11275 entries, 0 to 11274
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ss_username  11275 non-null  object
#  1   cf_username  11068 non-null  object
#  2   cf_rating    7437 non-null   float64
#  3   cc_username  10280 non-null  object
#  4   cc_rating    10280 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 440.6+ KB

# %%
data=df.dropna()

# %%
data.shape
# Out:
# (6442, 5)

# %%
x=data["cc_rating"]
y=data["cf_rating"]
print(x)
print(y)
# Out:
# 0        3007.0
# 4        2673.0
# 5        2628.0
# 6        2628.0
# 7        2565.0
#           ...
# 10269     580.0
# 10270     569.0
# 10272     518.0
# 10274     460.0
# 10278     277.0
# Name: cc_rating, Length: 6442, dtype: float64
# 0        3449.0
# 4        1703.0
# 5        2202.0
# 6        2262.0
# 7        2023.0
#           ...
# 10269     624.0
# 10270    1182.0
# 10272     979.0
# 10274    1581.0
# 10278     830.0
# Name: cf_rating, Length: 6442, dtype: float64

# %% [markdown]
# <h6>Estimating coefficients</h6>

# %%
x_mean = np.mean(x) 
y_mean = np.mean(y)

n = len(x)

num = 0
den = 0
for idx in x.index:
    num += (x[idx] - x_mean) * (y[idx] - y_mean)
    den += (x[idx] - x_mean) ** 2

b1 = num / den
b0 = y_mean - (b1*x_mean)

print("Calculated coefficients are:")
print("Slope is : ",b1,"and ","constant is",b0)

y_pred = x*b1 + b0
# Out:
# Calculated coefficients are:
# Slope is :  0.8315620555789279 and  constant is -32.629265073148645

# %% [markdown]
# <h6>Plotting regression line</h6>

# %%
plt.scatter(x,y,color="black")
plt.xlabel("Codechef ratings")
plt.ylabel("Codeforces ratings")
plt.title("Regression Plot", color="blue")
plt.plot(x,y_pred,color="red")
plt.show()

# %%
#b_0 = -32.62926507315615
#b_1 = 0.8315620555789324

def fun(codechef_rating):
    codeforces_rating=(codechef_rating*b1)+b0
    return codeforces_rating

# %%
##DEPLOYMENT
## run "https://chitra2445-ml-stream-ma-uzsnz2.streamlit.app/"
