# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/final_cccf.csv')

# %%
data
# Out:
#        ss_username     cf_username  cf_rating     cc_username  cc_rating
# 0         eldnahon           slime     3449.0  peehs_moorhsum     3007.0
# 1             jora             NaN        NaN             uwi     2906.0
# 2             lala             NaN        NaN          kal013     2756.0
# 3          wesnerm             NaN        NaN          wmoise     2696.0
# 4       grebnesieh      grebnesieh     1703.0      grebnesieh     2673.0
# ...            ...             ...        ...             ...        ...
# 11270       TeaPot          teapot     2677.0             NaN        NaN
# 11271    luosiyuan          tianbu     2882.0             NaN        NaN
# 11272    dorijanko  dorijanlendvaj     3120.0             NaN        NaN
# 11273     gamegame        gamegame     3218.0             NaN        NaN
# 11274  0xrayhansec         tourist     3764.0             NaN        NaN
#
# [11275 rows x 5 columns]

# %%
filteredData = data.dropna(subset=['cf_rating','cc_rating'])

# %%
filteredData = filteredData.astype({"cf_rating" : int, "cc_rating" : int})
filteredData.dtypes
# Out:
# ss_username    object
# cf_username    object
# cf_rating       int64
# cc_username    object
# cc_rating       int64
# dtype: object

# %%
filteredData
# Out:
#           ss_username        cf_username  cf_rating     cc_username  cc_rating
# 0            eldnahon              slime       3449  peehs_moorhsum       3007
# 4          grebnesieh         grebnesieh       1703      grebnesieh       2673
# 5           aurinegro          aurinegro       2202       aurinegro       2628
# 6           retrograd          retrograd       2262       retrograd       2628
# 7             chris19        anudeep2011       2023     anudeep2011       2565
# ...               ...                ...        ...             ...        ...
# 10269      Prince_Raj             daud43        624        praj0609        580
# 10270    Notanonymous  bhardwajarpit1998       1182       arpit_987        569
# 10272        yash1399           yash1399        979        yash1399        518
# 10274  hihihihipathak      praveenpathak       1581  hihihihipathak        460
# 10278        octamois      anmolmishra54        830     anmolmishra        277
#
# [6442 rows x 5 columns]

# %%
filteredData.plot.scatter(x = "cf_rating", y = "cc_rating", color = "black", alpha =0.3)
# Out:
# <Axes: xlabel='cf_rating', ylabel='cc_rating'>

# %%
def linearModel_ccratings(weight, intercept,cfRating):
  ccRating = weight*cfRating + intercept
  return ccRating

# %%
import numpy as np

weight1 = 0.79
intercept1 = 575

cfRating_range = np.linspace(filteredData["cf_rating"].min(), filteredData["cf_rating"].max(), num = 6440)
predicted_ccRatings = linearModel_ccratings(weight1, intercept1, cfRating_range)

# %%
filteredData.plot.scatter(x = "cf_rating", y = "cc_rating", color = "black", alpha =0.5)
plt.plot(cfRating_range, predicted_ccRatings, color = "blue")

# %%
filteredData.plot.scatter(x = "cc_rating", y = "cf_rating", color = "black", alpha =0.3)
# Out:
# <Axes: xlabel='cc_rating', ylabel='cf_rating'>

# %%
def linearModel_cfratings(weight, intercept,ccRating):
  cfRating = weight*ccRating + intercept
  return cfRating

# %%
weight2 = 1.15
intercept2 = -550

ccRating_range = np.linspace(filteredData["cc_rating"].min(), filteredData["cc_rating"].max(), num = 6440)
predicted_cfRatings = linearModel_cfratings(weight2, intercept2, ccRating_range)

# %%
filteredData.plot.scatter( x = "cc_rating",y = "cf_rating", color = "black", alpha =0.5)
plt.plot(ccRating_range, predicted_cfRatings, color = "blue")
