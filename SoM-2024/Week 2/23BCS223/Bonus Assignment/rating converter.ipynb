# %% [markdown]
# Importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the dataframe

# %%
df=pd.read_csv("final_cccf.csv")
df.shape
# Out:
# (11275, 5)

# %%
df.head(5)
# Out:
#   ss_username cf_username  cf_rating     cc_username  cc_rating
# 0    eldnahon       slime     3449.0  peehs_moorhsum     3007.0
# 1        jora         NaN        NaN             uwi     2906.0
# 2        lala         NaN        NaN          kal013     2756.0
# 3     wesnerm         NaN        NaN          wmoise     2696.0
# 4  grebnesieh  grebnesieh     1703.0      grebnesieh     2673.0

# %%
x=df['cc_rating']
y=df['cf_rating']
x=x.dropna()
y=y.dropna()
print(len(x),len(y))
# Out:
# 10280 7437

# %%
df1=df.dropna()
x=df1['cc_rating'].values
y=df1['cf_rating'].values

# %%
df1
# Out:
#           ss_username        cf_username  cf_rating     cc_username  cc_rating
# 0            eldnahon              slime     3449.0  peehs_moorhsum     3007.0
# 4          grebnesieh         grebnesieh     1703.0      grebnesieh     2673.0
# 5           aurinegro          aurinegro     2202.0       aurinegro     2628.0
# 6           retrograd          retrograd     2262.0       retrograd     2628.0
# 7             chris19        anudeep2011     2023.0     anudeep2011     2565.0
# ...               ...                ...        ...             ...        ...
# 10269      Prince_Raj             daud43      624.0        praj0609      580.0
# 10270    Notanonymous  bhardwajarpit1998     1182.0       arpit_987      569.0
# 10272        yash1399           yash1399      979.0        yash1399      518.0
# 10274  hihihihipathak      praveenpathak     1581.0  hihihihipathak      460.0
# 10278        octamois      anmolmishra54      830.0     anmolmishra      277.0
#
# [6442 rows x 5 columns]

# %%
plt.scatter(x,y)
plt.title("Scatter Plot CC vs CF")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mean_x=x.mean()
mean_y=y.mean()
m=len(x)
numer = 0
denom = 0
for i in range(m):
  numer += (x[i] - mean_x) * (y[i] - mean_y)
  denom += (x[i] - mean_x) ** 2
m = numer / denom
c = mean_y - (m * mean_x)
print(m,c)
# Out:
# 0.8315620555789317 -32.62926507315501

# %%
rangex=np.linspace(x.min(),x.max(),num=200)
predicted_cf=(m*rangex)+c
plt.plot(rangex,predicted_cf,color='black',label="Regression Line")
plt.scatter(x,y,label="Actual data points")
plt.ylabel("Codeforces Rating")
plt.xlabel("Codechef Rating")
plt.legend()
plt.show()

# %%
def predict(codechef_rating):
    codeforces_rating=(codechef_rating*m)+c
    return codeforces_rating
    
for a in range(700,2100,20):
    print("Codechef :",a,"Codeforces :",int(predict(a)))
# Out:
# Codechef : 700 Codeforces : 549
# Codechef : 720 Codeforces : 566
# Codechef : 740 Codeforces : 582
# Codechef : 760 Codeforces : 599
# Codechef : 780 Codeforces : 615
# Codechef : 800 Codeforces : 632
# Codechef : 820 Codeforces : 649
# Codechef : 840 Codeforces : 665
# Codechef : 860 Codeforces : 682
# Codechef : 880 Codeforces : 699
# Codechef : 900 Codeforces : 715
# Codechef : 920 Codeforces : 732
# Codechef : 940 Codeforces : 749
# Codechef : 960 Codeforces : 765
# Codechef : 980 Codeforces : 782
# Codechef : 1000 Codeforces : 798
# Codechef : 1020 Codeforces : 815
# Codechef : 1040 Codeforces : 832
# Codechef : 1060 Codeforces : 848
# Codechef : 1080 Codeforces : 865
# Codechef : 1100 Codeforces : 882
# Codechef : 1120 Codeforces : 898
# Codechef : 1140 Codeforces : 915
# Codechef : 1160 Codeforces : 931
# Codechef : 1180 Codeforces : 948
# Codechef : 1200 Codeforces : 965
# Codechef : 1220 Codeforces : 981
# Codechef : 1240 Codeforces : 998
# ...
