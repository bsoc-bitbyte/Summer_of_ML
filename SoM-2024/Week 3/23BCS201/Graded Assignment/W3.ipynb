# %% [markdown]
# # SA-2023 WEEK 3 GRADED ASSIGNMENT
#
# > Spaceship Titanic
#
# Predict which passengers are transported to an alternate dimension
#
# ![](https://www.gannett-cdn.com/-mm-/682bf77435754aee88576469063388a7d8b07c2a/c=0-150-1280-873/local/-/media/2017/02/01/Reno/RGJ/636215634914521096-image001.jpg?width=660&height=373&fit=crop&format=pjpg&auto=webp)

# %% [markdown]
# ### <b>Description</b>
#
# Welcome to the year 2912, where your data science skills are needed to solve a cosmic mystery. We've received a transmission from four lightyears away and things aren't looking good.
#
# The Spaceship Titanic was an interstellar passenger liner launched a month ago. With almost 13,000 passengers on board, the vessel set out on its maiden voyage transporting emigrants from our solar system to three newly habitable exoplanets orbiting nearby stars.
#
# While rounding Alpha Centauri en route to its first destination—the torrid 55 Cancri E—the unwary Spaceship Titanic collided with a spacetime anomaly hidden within a dust cloud. Sadly, it met a similar fate as its namesake from 1000 years before. Though the ship stayed intact, almost half of the passengers were transported to an alternate dimension!

# %% [markdown]
# ### <b>Data description</b>
#
# - Personal records for about two-thirds (~8700) of the passengers, to be used as training data.
# - <code>PassengerId</code> - A unique Id for each passenger. Each Id takes the form gggg_pp where gggg indicates a group the passenger is travelling with and pp is their number within the group. People in a group are often family members, but not always.
# - <code>HomePlanet</code> - The planet the passenger departed from, typically their planet of permanent residence.
# - <code>CryoSleep</code> - Indicates whether the passenger elected to be put into suspended animation for the duration of the voyage. Passengers in cryosleep are confined to their cabins.
# - <code>Cabin</code> - The cabin number where the passenger is staying. Takes the form deck/num/side, where side can be either P for Port or S for Starboard.
# - <code>Destination</code> - The planet the passenger will be debarking to.
# - <code>Age</code> - The age of the passenger.
# - <code>VIP</code> - Whether the passenger has paid for special VIP service during the voyage.
# - <code>RoomService, FoodCourt, ShoppingMall, Spa, VRDeck</code> - Amount the passenger has billed at each of the Spaceship Titanic's many luxury amenities.
# - <code>Name</code> - The first and last names of the passenger.
# - <code>Transported</code> - Whether the passenger was transported to another dimension. This is the target, the column you are trying to predict.

# %% [markdown]
# ### <b>Algorithm Documentation</b> (Highly recommended!)
# - <code>Logistic Regression</code> : https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
# - <code>SVM</code> : https://scikit-learn.org/stable/modules/svm.html
# Confusion Matrix : https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html
# - <code>Plot Confusion Matrix</code> : https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html
# - <code>ROC_AUC Score</code> : https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html#sklearn.metrics.roc_auc_score
# - <code>Classification Report</code> : https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html
# - <code>Label Encoder</code> : https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html
# - <code>Label Binarizer</code> : https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelBinarizer.html
# - <code>Standard Scaler</code> : https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
# - <code>Cross Val Score</code> : https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html

# %% [markdown]
# # <span><h1 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color: #f6f5f5; color :#fe346e; border-radius: 100px 100px; text-align:center">Install Required Libraries</h1></span>

# %%
## ======== YOUR CODE HERE ======== ##

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, classification_report, roc_curve 
# from sklearn.metrics import plot_confusion_matrix
from sklearn.preprocessing import LabelEncoder, LabelBinarizer, StandardScaler


from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Read the data

# %%
## ======== YOUR CODE HERE ======== ##

# Use df as the dataframe name throughout the notebook.
df = pd.read_csv(r'C:\local disk D\codes\ai and ml\jupyter\som\weeks\week 3\data.csv')
df.head()

## ================================ ##
# Out:
#   PassengerId HomePlanet  CryoSleep  Cabin Destination  Age    VIP  \
# 0     0001_01     Europa      False  B/0/P   Andromeda   39  False
# 1     0002_01      Earth      False  F/0/S   Andromeda   24  False
# 2     0003_01     Europa      False  A/0/S   Andromeda   58   True
# 3     0003_02     Europa      False  A/0/S   Andromeda   33  False
# 4     0004_01      Earth      False  F/1/S   Andromeda   16  False
#
#    RoomService  FoodCourt  ShoppingMall   Spa  VRDeck               Name  \
# 0            0          0             0     0       0    Maham Ofracculy
# 1          109          9            25   549      44       Juanna Vines
# 2           43       3576             0  6715      49      Altark Susent
# 3            0       1283           371  3329     193       Solam Susent
# 4          303         70           151   565       2  Willy Santantines
#
#    Transported
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True

# %% [markdown]
# #### Check the shape of data. It should be  (8693, 14)

# %%
## ======== YOUR CODE HERE ======== ##
df.shape



## ================================ ##
# Out:
# (8693, 14)

# %% [markdown]
# #### Apply describe on dataframe

# %%
## ======== YOUR CODE HERE ======== ##
df.describe()


## ================================ ##
# Out:
#                Age   RoomService     FoodCourt  ShoppingMall           Spa  \
# count  8693.000000   8693.000000   8693.000000   8693.000000   8693.000000
# mean     28.728517    220.009318    448.434027    169.572300    304.588865
# std      14.355438    660.519050   1595.790627    598.007164   1125.562559
# min       0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      20.000000      0.000000      0.000000      0.000000      0.000000
# 50%      27.000000      0.000000      0.000000      0.000000      0.000000
# 75%      37.000000     41.000000     61.000000     22.000000     53.000000
# max      79.000000  14327.000000  29813.000000  23492.000000  22408.000000
#
#              VRDeck
# count   8693.000000
# mean     298.261820
# std     1134.126417
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       40.000000
# max    24133.000000

# %% [markdown]
# #### Check if there any null value in the dataset.

# %%
## ======== YOUR CODE HERE ======== ##
df.isnull().sum()



## ================================ ##
# Out:
# PassengerId     0
# HomePlanet      0
# CryoSleep       0
# Cabin           0
# Destination     0
# Age             0
# VIP             0
# RoomService     0
# FoodCourt       0
# ShoppingMall    0
# Spa             0
# VRDeck          0
# Name            0
# Transported     0
# dtype: int64

# %%
#checking for unique values in the dataset
df.nunique()
# Out:
# PassengerId     8693
# HomePlanet         3
# CryoSleep          2
# Cabin           6560
# Destination        3
# Age               80
# VIP                2
# RoomService     1273
# FoodCourt       1507
# ShoppingMall    1115
# Spa             1327
# VRDeck          1306
# Name            8473
# Transported        2
# dtype: int64

# %% [markdown]
# #### Number continuous and categorical features

# %%
#################################################################

# Don't make mistake here. Ask in the discussion section if you are stuck. Help will be provided....

#################################################################

## ======== YOUR CODE HERE ======== ##



continous_features = ['Age','RoomService','FoodCourt','ShoppingMall','Spa','VRDeck'] # Fill the continuous fearures inside the array

categorical_features = ['PassengerId','HomePlanet','CryoSleep','Cabin','Destination','VIP','Name','Transported'] # Fill the categorical features inside the array

## ======== YOUR CODE HERE ======== ##

print("Continous Features: ", continous_features)
print("No. of Continuous features: ", len(continous_features))

print("Categorical Features: ", categorical_features)
print("No. of Categorical Features: ", len(categorical_features))
# Out:
# Continous Features:  ['Age', 'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck']
# No. of Continuous features:  6
# Categorical Features:  ['PassengerId', 'HomePlanet', 'CryoSleep', 'Cabin', 'Destination', 'VIP', 'Name', 'Transported']
# No. of Categorical Features:  8

# %% [markdown]
# #### Unique values

# %%
# Print the number of unique values of the categorical features

## ======== YOUR CODE HERE ======== ##
a=df[categorical_features].nunique()
print(a)




## ======== YOUR CODE HERE ======== ##
# Out:
# PassengerId    8693
# HomePlanet        3
# CryoSleep         2
# Cabin          6560
# Destination       3
# VIP               2
# Name           8473
# Transported       2
# dtype: int64

# %% [markdown]
# <code>Note: If we apply one-hot-encoding to a categorical feature with many unique values, </code>
# - Number of columns will be high
# - Time required for training a model will be high
# - We may not get usefull insights about the data
#
# <code>This is the reason we are droping the features with more unique values.</code>

# %% [markdown]
# #### Drop the features

# %%
# Drop those categorical features which have more than 25 unique values

## ======== YOUR CODE HERE ======== ##
cols_to_drop = df[categorical_features].nunique()[df[categorical_features].nunique()>25].index
df.drop(columns=cols_to_drop, axis=1, inplace=True)
categorical_features=[col for col in categorical_features if col not in cols_to_drop]



## ======== YOUR CODE HERE ======== ##

# Print the shape after droping the features
# Check: Shape --> (8693, 11)
df.shape




## ======== YOUR CODE HERE ======== ##



## ======== YOUR CODE HERE ======== ##
# Out:
# (8693, 11)

# %%
df[categorical_features]
# Out:
#      HomePlanet  CryoSleep Destination    VIP  Transported
# 0        Europa      False   Andromeda  False        False
# 1         Earth      False   Andromeda  False         True
# 2        Europa      False   Andromeda   True        False
# 3        Europa      False   Andromeda  False        False
# 4         Earth      False   Andromeda  False         True
# ...         ...        ...         ...    ...          ...
# 8688     Europa      False       Virgo   True        False
# 8689      Earth       True      Cygnus  False        False
# 8690      Earth      False   Andromeda  False         True
# 8691     Europa      False       Virgo  False        False
# 8692     Europa      False   Andromeda  False         True
#
# [8693 rows x 5 columns]

# %%
df[categorical_features].nunique()
# Out:
# HomePlanet     3
# CryoSleep      2
# Destination    3
# VIP            2
# Transported    2
# dtype: int64

# %%
categorical_features
# Out:
# ['HomePlanet', 'CryoSleep', 'Destination', 'VIP', 'Transported']

# %%
df.head()
# Out:
#   HomePlanet  CryoSleep Destination  Age    VIP  RoomService  FoodCourt  \
# 0     Europa      False   Andromeda   39  False            0          0
# 1      Earth      False   Andromeda   24  False          109          9
# 2     Europa      False   Andromeda   58   True           43       3576
# 3     Europa      False   Andromeda   33  False            0       1283
# 4      Earth      False   Andromeda   16  False          303         70
#
#    ShoppingMall   Spa  VRDeck  Transported
# 0             0     0       0        False
# 1            25   549      44         True
# 2             0  6715      49        False
# 3           371  3329     193        False
# 4           151   565       2         True

# %% [markdown]
# #### One Hot Encoding

# %%
# Hint: search for get_dummies

## ======== YOUR CODE HERE ======== ##
df = pd.get_dummies(df) 

#here we have not ignored dummies value trap because we have already removed the columns with more than 25 unique values






## ======== YOUR CODE HERE ======== ##


# Check: Shape --> (8693, 15)

# %%
df.shape
# Out:
# (8693, 15)

# %%
df.head()
# Out:
#    CryoSleep  Age    VIP  RoomService  FoodCourt  ShoppingMall   Spa  VRDeck  \
# 0      False   39  False            0          0             0     0       0
# 1      False   24  False          109          9            25   549      44
# 2      False   58   True           43       3576             0  6715      49
# 3      False   33  False            0       1283           371  3329     193
# 4      False   16  False          303         70           151   565       2
#
#    Transported  HomePlanet_Earth  HomePlanet_Europa  HomePlanet_Mars  \
# 0        False             False               True            False
# 1         True              True              False            False
# 2        False             False               True            False
# 3        False             False               True            False
# 4         True              True              False            False
#
#    Destination_Andromeda  Destination_Cygnus  Destination_Virgo
# ...

# %% [markdown]
# #### Changing bool columns to 0,1

# %%
## ======== Run this code(Don't change any code)======== ##

df['CryoSleep'] = df['CryoSleep'].astype(int)
df['VIP'] = df['VIP'].astype(int)
df['Transported'] = df['Transported'].astype(int)

df.head()

## ======== Run this code(Don't change any code)======== ##
# Out:
#    CryoSleep  Age  VIP  RoomService  FoodCourt  ShoppingMall   Spa  VRDeck  \
# 0          0   39    0            0          0             0     0       0
# 1          0   24    0          109          9            25   549      44
# 2          0   58    1           43       3576             0  6715      49
# 3          0   33    0            0       1283           371  3329     193
# 4          0   16    0          303         70           151   565       2
#
#    Transported  HomePlanet_Earth  HomePlanet_Europa  HomePlanet_Mars  \
# 0            0             False               True            False
# 1            1              True              False            False
# 2            0             False               True            False
# 3            0             False               True            False
# 4            1              True              False            False
#
#    Destination_Andromeda  Destination_Cygnus  Destination_Virgo
# ...

# %%
df['HomePlanet_Earth'] = df['HomePlanet_Earth'].astype(int)
df['HomePlanet_Europa'] = df['HomePlanet_Europa'].astype(int)
df['HomePlanet_Mars'] = df['HomePlanet_Mars'].astype(int)

df['Destination_Andromeda'] = df['Destination_Andromeda'].astype(int)
df['Destination_Cygnus'] = df['Destination_Cygnus'].astype(int)
df['Destination_Virgo'] = df['Destination_Virgo'].astype(int)

# %%
df.head()
# Out:
#    CryoSleep  Age  VIP  RoomService  FoodCourt  ShoppingMall   Spa  VRDeck  \
# 0          0   39    0            0          0             0     0       0
# 1          0   24    0          109          9            25   549      44
# 2          0   58    1           43       3576             0  6715      49
# 3          0   33    0            0       1283           371  3329     193
# 4          0   16    0          303         70           151   565       2
#
#    Transported  HomePlanet_Earth  HomePlanet_Europa  HomePlanet_Mars  \
# 0            0                 0                  1                0
# 1            1                 1                  0                0
# 2            0                 0                  1                0
# 3            0                 0                  1                0
# 4            1                 1                  0                0
#
#    Destination_Andromeda  Destination_Cygnus  Destination_Virgo
# ...

# %% [markdown]
# #### Split the data into train and test

# %%
## ======== YOUR CODE HERE ======== ##

## Test size should be 15% of the full dataset and use random state = 2022

X = df.drop(columns='Transported', axis=1)
y = df['Transported']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=2022)

## ================================ ##

# %%
## ======== YOUR CODE HERE ======== ##

   ## Let us print the shapes:

print("X_train:", X_train.shape) # X_train
print("X_test:",X_test.shape) # X_test
print("y_train:",y_train.shape) # y_train
print("y_test:",y_test.shape) # y_test_________

## ================================ ##
# Out:
# X_train: (7389, 14)
# X_test: (1304, 14)
# y_train: (7389,)
# y_test: (1304,)

# %% [markdown]
# #### Scale the data using Standard Scaler

# %%
## Use Standard Scaler to scale the train and test data

## ======== YOUR CODE HERE ======== ##
scaler=StandardScaler()
#fit and transform the train data
X_train_scaled=scaler.fit_transform(X_train)
#transform the test data
X_test_scaled=scaler.transform(X_test)
## ================================ ##

# %% [markdown]
# ## <b>Logistic Regression</b>
# #### Use default parameters unless mentioned

# %%
## Use Random state = 2021 and fit the LR model

## ======== YOUR CODE HERE ======== ##
logisticregr = LogisticRegression(random_state=2021)
logisticregr.fit(X_train_scaled, y_train)



## ================================ ##
# Out:
# LogisticRegression(random_state=2021)

# %% [markdown]
# #### Plot confusion matrix

# %%
#confusion matrix
y_pred = logisticregr.predict(X_test_scaled)
cm = confusion_matrix(y_test, y_pred, labels=[1, 0])

# %%
## ======== YOUR CODE HERE ======== ##

sns.heatmap(cm, annot=True, fmt='d', cmap='Blues' , xticklabels=['Positive', 'Negative'], yticklabels=['1', '0'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()



## ================================ ##

# %% [markdown]
# #### Print classification report

# %%
## ======== YOUR CODE HERE ======== ##

y_pred_test = logisticregr.predict(X_test_scaled)
print(classification_report(y_test, y_pred_test))

## ================================ ##
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79       637
#            1       0.81      0.79      0.80       667
#
#     accuracy                           0.79      1304
#    macro avg       0.79      0.79      0.79      1304
# weighted avg       0.79      0.79      0.79      1304

# %% [markdown]
# #### Print accuracy score

# %%
## ======== YOUR CODE HERE ======== ##

print('Accuracy: ', accuracy_score(y_test,y_pred_test))

## ================================ ##
# Out:
# Accuracy:  0.7944785276073619

# %% [markdown]
# #### Print ROC-AUC score

# %%
## ======== YOUR CODE HERE ======== ##

## Note: Use predict_proba!!! Read documentation/google it
y_pred_proba = logisticregr.predict_proba(X_test_scaled)
roc_auc = roc_auc_score(y_test, y_pred_proba[:,1])
print('ROC AUC Score: ', roc_auc)

## ================================ ##
# Out:
# ROC AUC Score:  0.877197978718647

# %% [markdown]
# #### Plot ROC-AUC Curve

# %%
## ======== YOUR CODE HERE ======== ##

## Set appropriate X label, Y label and Title for the graph
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba[:,1])

plt.figure(figsize=(6,6))
plt.plot(fpr,tpr,'-g',linewidth=1)
plt.plot([0,1], [0,1], 'k--' )
plt.title('ROC curve')
plt.xlabel("False Positive Rate")
plt.ylabel('True Positive Rate')
plt.show()



## ================================ ##

# %% [markdown]
# #### Cross validation

# %%
## ======== YOUR CODE HERE ======== ##


## cv=5
scores = cross_val_score(logisticregr, X_train_scaled, y_train, cv = 5)

print(f'Cross-validation scores: {scores}')
print(f'Mean of cross-validation scores: {scores.mean()}')




## ================================ ##
# Out:
# Cross-validation scores: [0.78619756 0.79364005 0.76792963 0.80243572 0.7731889 ]
# Mean of cross-validation scores: 0.7846783746815171

# %% [markdown]
# ## <b>SVM</b>
# #### Use default parameters unless mentioned

# %%
## ======== YOUR CODE HERE ======== ##

## parameters: random_state = 2022, C=5, gamma='scale', kernel='rbf', probability=True
support = SVC(random_state=2022, C=5, gamma='scale', kernel='rbf', probability=True)
support.fit(X_train_scaled, y_train)



## ================================ ##
# Out:
# SVC(C=5, probability=True, random_state=2022)

# %% [markdown]
# #### Plot confusion matrix

# %%
## ======== YOUR CODE HERE ======== ##

## Use display labels as per your choice.
#confusion matrix
y_pred_svm = support.predict(X_test_scaled)
cm_svm = confusion_matrix(y_test, y_pred_svm , labels=[1, 0])
sns.heatmap(cm_svm, annot=True, fmt='d', cmap='rocket', xticklabels=['Positive', 'Negative'], yticklabels=['1', '0'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()





## ================================ ##

# %% [markdown]
# #### Print classification report

# %%
## ======== YOUR CODE HERE ======== ##

y_pred_svm = support.predict(X_test_scaled)
print(classification_report(y_test, y_pred_svm))

## ================================ ##
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.80       637
#            1       0.81      0.81      0.81       667
#
#     accuracy                           0.80      1304
#    macro avg       0.80      0.80      0.80      1304
# weighted avg       0.80      0.80      0.80      1304

# %% [markdown]
# #### Print accuracy score

# %%
## ======== YOUR CODE HERE ======== ##

print('Accuracy: ', accuracy_score(y_test, y_pred_svm))

## ================================ ##
# Out:
# Accuracy:  0.8044478527607362

# %% [markdown]
# #### Print ROC-AUC score

# %%
## ======== YOUR CODE HERE ======== ##

## Note: Use predict_proba!!! Read documentation/google it
y_pred_svm = support.predict_proba(X_test_scaled)
roc_auc_svm = roc_auc_score(y_test, y_pred_svm[:,1])
print('ROC AUC Score: ', roc_auc_svm)




## ================================ ##
# Out:
# ROC AUC Score:  0.8687238013646239

# %% [markdown]
# #### Plot ROC-AUC curve

# %%
## ======== YOUR CODE HERE ======== ##

## Set appropriate X label, Y label and Title for the graph


pred_svm_proba = support.predict_proba(X_test_scaled)
fpr1, tpr1, thresholds1 = roc_curve(y_test, pred_svm_proba[:,1])

plt.figure(figsize=(6,4))
plt.plot(fpr1,tpr1,'-r',linewidth=1)
plt.plot([0,1], [0,1], 'k--' )
plt.title('ROC curve for SVM model')
plt.xlabel("False Positive Rate")
plt.ylabel('True Positive Rate')
plt.show()

## ================================ ##

# %% [markdown]
# #### Cross validation

# %%
## ======== YOUR CODE HERE ======== ##

## cv=5
scores1 = cross_val_score(support, X_train_scaled, y_train, cv = 5)

print(f'Cross-validation scores: {scores1}')
print(f'Mean of cross-validation scores: {scores1.mean()}')




## ================================ ##
# Out:
# Cross-validation scores: [0.79093369 0.78755074 0.76454668 0.80514208 0.77386594]
# Mean of cross-validation scores: 0.7844078303037189

# %% [markdown]
# # Congratulations! Assignment Completed!
