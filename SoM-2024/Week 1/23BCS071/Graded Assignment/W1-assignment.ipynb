# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first graded assignment! Hope that you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We have got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
import pandas as pd

pokemons = pd.read_csv('W1_Pokemon.csv')

pokemons1 = pokemons.copy()
pokemons
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
#your code here
pokemons.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
pokemons.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
#your code here
pokemons = pokemons.drop("#",axis=1)
pokemons
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
#your code here
pokemons = pokemons.set_index('Name')
pokemons
# Out:
#                         Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                Grass  Poison    318  45      49       49       65
# Ivysaur                  Grass  Poison    405  60      62       63       80
# Venusaur                 Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur    Grass  Poison    625  80     100      123      122
# Charmander                Fire     NaN    309  39      52       43       60
# ...                        ...     ...    ...  ..     ...      ...      ...
# Diancie                   Rock   Fairy    600  50     100      150      100
# DiancieMega Diancie       Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined    Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound     Psychic    Dark    680  80     160       60      170
# Volcanion                 Fire   Water    600  80     110      120      130
#
# ...

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
#your code here
pokemons["Type 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
#your code here
pokemons["powers"] = ""
for i in range(800):
  pokemons.loc[pokemons.index[i], "powers"] = str(pokemons.loc[pokemons.index[i], "Type 1"]) + ' + ' + str(pokemons.loc[pokemons.index[i], "Type 2"])
pokemons
# Out:
#                         Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Bulbasaur                Grass  Poison    318  45      49       49       65
# Ivysaur                  Grass  Poison    405  60      62       63       80
# Venusaur                 Grass  Poison    525  80      82       83      100
# VenusaurMega Venusaur    Grass  Poison    625  80     100      123      122
# Charmander                Fire     NaN    309  39      52       43       60
# ...                        ...     ...    ...  ..     ...      ...      ...
# Diancie                   Rock   Fairy    600  50     100      150      100
# DiancieMega Diancie       Rock   Fairy    700  50     160      110      160
# HoopaHoopa Confined    Psychic   Ghost    600  80     110       60      150
# HoopaHoopa Unbound     Psychic    Dark    680  80     160       60      170
# Volcanion                 Fire   Water    600  80     110      120      130
#
# ...

# %%
pokemons[(pokemons["Type 1"]=='Psychic') &
         (pokemons["Type 2"]=='Flying')]
# Out:
#            Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Natu      Psychic  Flying    320   40      50       45       70       45
# Xatu      Psychic  Flying    470   65      75       70       95       70
# Lugia     Psychic  Flying    680  106      90      130       90      154
# Woobat    Psychic  Flying    313   55      45       43       55       43
# Swoobat   Psychic  Flying    425   67      57       55       77       55
# Sigilyph  Psychic  Flying    490   72      58       80      103       80
#
#           Speed  Generation  Legendary            powers
# Name
# Natu         70           2      False  Psychic + Flying
# Xatu         95           2      False  Psychic + Flying
# Lugia       110           2       True  Psychic + Flying
# Woobat       72           5      False  Psychic + Flying
# Swoobat     114           5      False  Psychic + Flying
# Sigilyph     97           5      False  Psychic + Flying

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
#your code here
pokemons.index.str.contains("Mega").sum()
# Out:
# 49

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
#your code here
pokemons["Sp. Def"].var()**(1/2)
# Out:
# 27.82891579711746

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
#your code here
legpokemons=pokemons[pokemons["Legendary"]==True]
print((len(legpokemons)/len(pokemons))*100)
# Out:
# 8.125

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
#your code here
maxdefense = pokemons["Defense"].max()
maxdefpokemons = pokemons[pokemons["Defense"]== maxdefense]
maxdefpokemons
# Out:
#                     Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# SteelixMega Steelix  Steel  Ground    610  75     125      230       55
# Shuckle                Bug    Rock    505  20      10      230       10
# AggronMega Aggron    Steel     NaN    630  70     140      230       60
#
#                      Sp. Def  Speed  Generation  Legendary          powers
# Name
# SteelixMega Steelix       95     30           2      False  Steel + Ground
# Shuckle                  230      5           2      False      Bug + Rock
# AggronMega Aggron         80     50           3      False     Steel + nan

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
#your code here
poipokemons = pokemons[pokemons["Type 1"]=="Poison"]
poipokemonsmaxatt=poipokemons["Attack"].max()
poipokemons[poipokemons["Attack"]==poipokemonsmaxatt]
# Out:
#            Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Toxicroak  Poison  Fighting    490  83     106       65       86       65
#
#            Speed  Generation  Legendary             powers
# Name
# Toxicroak     85           4      False  Poison + Fighting

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
#your code here

# %%
#your code here

# %%
#your code here

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
nonlegpokemons = pokemons[pokemons["Legendary"]==False]
nonleggost=nonlegpokemons[nonlegpokemons["Type 1"].isin(["Ghost"]) | nonlegpokemons["Type 2"].isin(["Ghost"])]
forthgen = nonleggost[nonleggost["Generation"]==4]
forthgenmax = forthgen.Speed.max()
forthgen1 = forthgen.copy()
sortforthgen1 = forthgen1.sort_values(by="Speed", ascending=True)
secfast = sortforthgen1.iloc[len(sortforthgen1)-2]
secfast
# Out:
# Type 1              Ghost
# Type 2                NaN
# Total                 495
# HP                     60
# Attack                 60
# Defense                60
# Sp. Atk               105
# Sp. Def               105
# Speed                 105
# Generation              4
# Legendary           False
# powers        Ghost + nan
# Name: Mismagius, dtype: object

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
#your code here

charizardatt = pokemons1[pokemons1["Name"] == "Charizard"]["Attack"].values[0]
charizarddef = pokemons1[pokemons1["Name"] == "Charizard"]["Defense"].values[0]


filterpokemons = pokemons1[(pokemons1["Legendary"] == False) &(pokemons1["Defense"] > charizarddef) &(pokemons1["Attack"] < charizardatt)]



len(filterpokemons)
# Out:
# 116

# %% [markdown]
# ## ***Bonus Questions***
# ## Here are some bonus questions that you can try further !
#
# ### These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
#your code here

pokemons["combinedatt"] = pokemons["Attack"] + pokemons["Sp. Atk"]
maxcom = pokemons["combinedatt"].max()
pokemonsmaxcom = pokemons[pokemons["combinedatt"] == maxcom]
pokemonsmaxcom
# Out:
#                         Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# RayquazaMega Rayquaza   Dragon  Flying    780  105     180      100      180
# DeoxysAttack Forme     Psychic     NaN    600   50     180       20      180
#
#                        Sp. Def  Speed  Generation  Legendary           powers  \
# Name
# RayquazaMega Rayquaza      100    115           3       True  Dragon + Flying
# DeoxysAttack Forme          20    150           3       True    Psychic + nan
#
#                        combinedatt
# Name
# RayquazaMega Rayquaza          360
# DeoxysAttack Forme             360

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
type1 = legpokemons["Type 1"].value_counts().sort_values(ascending=False)

type1.index[0]
# Out:
# 'Psychic'

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
gen6leg = pokemons[pokemons["Legendary"]==True]
gen6week = gen6leg[gen6leg["Generation"]==6].HP.min()
gen3nonleg = pokemons[pokemons["Legendary"]==False]
gen3 = gen3nonleg[gen3nonleg["Generation"]==3]
num = gen3[gen3["HP"]>gen6week]
len(num)
# Out:
# 95

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here
pokemons1speed = pokemons1.sort_values(by="Speed", ascending=True)
pokemons1speed.iloc[2]
# Out:
# #                   597
# Name          Ferroseed
# Type 1            Grass
# Type 2            Steel
# Total               305
# HP                   44
# Attack               50
# Defense              91
# Sp. Atk              24
# Sp. Def              86
# Speed                10
# Generation            5
# Legendary         False
# Name: 658, dtype: object

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
#your code here
avghp = pokemons.groupby('Type 1')['HP'].mean()
highestavghp = avghp.idxmax()
highestavghp
# Out:
# 'Dragon'
