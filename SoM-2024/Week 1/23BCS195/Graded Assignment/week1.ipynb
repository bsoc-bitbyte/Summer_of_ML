# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first graded assignment! Hope that you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We have got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df = pd.read_csv('/content/drive/MyDrive/W1_Pokemon.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
#your code here
df.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
#your code here
df.drop('#', axis=1, inplace=True)

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
#your code here
df.set_index('Name', inplace=True)

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
#your code here
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
#your code here
df['Types Combo'] = df['Type 1'] + ' + ' + df['Type 2']
df.loc[(df['Types Combo'] == 'Psychic + Flying') ]
# Out:
#            Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Natu      Psychic  Flying    320   40      50       45       70       45
# Xatu      Psychic  Flying    470   65      75       70       95       70
# Lugia     Psychic  Flying    680  106      90      130       90      154
# Woobat    Psychic  Flying    313   55      45       43       55       43
# Swoobat   Psychic  Flying    425   67      57       55       77       55
# Sigilyph  Psychic  Flying    490   72      58       80      103       80
#
#           Speed  Generation  Legendary       Types Combo
# Name
# Natu         70           2      False  Psychic + Flying
# Xatu         95           2      False  Psychic + Flying
# Lugia       110           2       True  Psychic + Flying
# Woobat       72           5      False  Psychic + Flying
# Swoobat     114           5      False  Psychic + Flying
# Sigilyph     97           5      False  Psychic + Flying

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
#your code here
df2 = df.loc[df.index.str.contains('Mega')]
df2.shape[0]
# Out:
# 49

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
#your code here
df['Sp. Def'].std()
# Out:
# 27.82891579711746

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
#your code here
df['Legendary'].value_counts(normalize=True)
# Out:
# Legendary
# False    0.91875
# True     0.08125
# Name: proportion, dtype: float64

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
#your code here
df.loc[df['Defense'] == df['Defense'].max()]
# Out:
#                     Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# SteelixMega Steelix  Steel  Ground    610  75     125      230       55
# Shuckle                Bug    Rock    505  20      10      230       10
# AggronMega Aggron    Steel     NaN    630  70     140      230       60
#
#                      Sp. Def  Speed  Generation  Legendary     Types Combo
# Name
# SteelixMega Steelix       95     30           2      False  Steel + Ground
# Shuckle                  230      5           2      False      Bug + Rock
# AggronMega Aggron         80     50           3      False             NaN

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
#your code here

df2 = df.loc[(df['Type 1'] == 'Poison') ]
df2.loc[df2['Attack'] == df2['Attack'].max()]
# Out:
#            Type 1    Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Toxicroak  Poison  Fighting    490  83     106       65       86       65
#
#            Speed  Generation  Legendary        Types Combo
# Name
# Toxicroak     85           4      False  Poison + Fighting

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
#your code here
sns.scatterplot(x='Attack', y='Defense', data=df)
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %%
#your code here
sns.barplot(x='Type 1', y='Defense', data=df)
# Out:
# <Axes: xlabel='Type 1', ylabel='Defense'>

# %%
#your code here
sns.boxplot(x='Type 1', y='Attack', data=df)
# Out:
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
#your code here
df.loc[(df['Type 1'] == 'Ghost') & (df['Generation'] == 4) & (df['Legendary'] == False)].sort_values('Speed', ascending=False).iloc[1]
# Out:
# Type 1                  Ghost
# Type 2                 Flying
# Total                     498
# HP                        150
# Attack                     80
# Defense                    44
# Sp. Atk                    90
# Sp. Def                    54
# Speed                      80
# Generation                  4
# Legendary               False
# Types Combo    Ghost + Flying
# Name: Drifblim, dtype: object

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
#your code here
df.loc[(df['Legendary'] == False) & (df['Attack'] < df.loc['Charizard']['Attack']) & (df['Defense'] > df.loc['Charizard']['Defense'])]
# Out:
#                      Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Venusaur              Grass  Poison    525  80      82       83      100
# Wartortle             Water     NaN    405  59      63       80       65
# Blastoise             Water     NaN    530  79      83      100       85
# PidgeotMega Pidgeot  Normal  Flying    579  83      80       80      135
# Sandshrew            Ground     NaN    300  50      75       85       20
# ...                     ...     ...    ...  ..     ...      ...      ...
# Clawitzer             Water     NaN    500  71      73       88      120
# Carbink                Rock   Fairy    500  50      50      150       50
# Klefki                Steel   Fairy    470  57      80       91       80
# Bergmite                Ice     NaN    304  55      69       85       32
# Noivern              Flying  Dragon    535  85      70       80       97
#
#                      Sp. Def  Speed  Generation  Legendary      Types Combo
# Name
# ...

# %% [markdown]
# ## ***Bonus Questions***
# ## Here are some bonus questions that you can try further !
#
# ### These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
#your code here
df['Attack + Sp.Atk'] = df['Attack'] + df['Sp. Atk']
df.loc[df['Attack + Sp.Atk'] == df['Attack + Sp.Atk'].max()]
# Out:
#                         Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# RayquazaMega Rayquaza   Dragon  Flying    780  105     180      100      180
# DeoxysAttack Forme     Psychic     NaN    600   50     180       20      180
#
#                        Sp. Def  Speed  Generation  Legendary      Types Combo  \
# Name
# RayquazaMega Rayquaza      100    115           3       True  Dragon + Flying
# DeoxysAttack Forme          20    150           3       True              NaN
#
#                        Attack + Sp.Atk
# Name
# RayquazaMega Rayquaza              360
# DeoxysAttack Forme                 360

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
#your code here
df.loc[df['Legendary'] == True]['Type 1'].value_counts().idxmax()

#Answer : Type 1 Psychic legendary pokemon are most common
# Out:
# 'Psychic'

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
#your code here
df.loc[(df['Generation'] == 3) & (df['Legendary'] == False) & (df['HP'] > df.loc[df['Generation'] == 6].sort_values('HP').iloc[0]['HP'])]
# Out:
#                          Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Name
# Treecko                   Grass      NaN    310  40      45       35       65
# Grovyle                   Grass      NaN    405  50      65       45       85
# Sceptile                  Grass      NaN    530  70      85       65      105
# SceptileMega Sceptile     Grass   Dragon    630  70     110       75      145
# Torchic                    Fire      NaN    310  45      60       40       70
# ...                         ...      ...    ...  ..     ...      ...      ...
# SalamenceMega Salamence  Dragon   Flying    700  95     145      130      120
# Beldum                    Steel  Psychic    300  40      55       80       35
# Metang                    Steel  Psychic    420  60      75      100       55
# Metagross                 Steel  Psychic    600  80     135      130       95
# MetagrossMega Metagross   Steel  Psychic    700  80     145      150      105
#
# ...

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here
df.sort_values('Speed', ascending=True).iloc[2]
# Out:
# Type 1                     Grass
# Type 2                     Steel
# Total                        305
# HP                            44
# Attack                        50
# Defense                       91
# Sp. Atk                       24
# Sp. Def                       86
# Speed                         10
# Generation                     5
# Legendary                  False
# Types Combo        Grass + Steel
# Attack + Sp.Atk               74
# Name: Ferroseed, dtype: object

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
df.groupby('Type 1')['HP'].mean().sort_values(ascending=False).idxmax()

#Answer : Dragon
# Out:
# 'Dragon'
