# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load the dataset

# %%
df1=pd.read_csv('world-happiness-report-2021.csv')

# %% [markdown]
# ## Read 5 values from start

# %%
df1.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %% [markdown]
# ##Read 10 values from end

# %%
df1.tail(10)
# Display last 10 observations
# Out:
#     Country name            Regional indicator  Ladder score  \
# 139      Burundi            Sub-Saharan Africa         3.775
# 140        Yemen  Middle East and North Africa         3.658
# 141     Tanzania            Sub-Saharan Africa         3.623
# 142        Haiti   Latin America and Caribbean         3.615
# 143       Malawi            Sub-Saharan Africa         3.600
# 144      Lesotho            Sub-Saharan Africa         3.512
# 145     Botswana            Sub-Saharan Africa         3.467
# 146       Rwanda            Sub-Saharan Africa         3.415
# 147     Zimbabwe            Sub-Saharan Africa         3.145
# 148  Afghanistan                    South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 139                           0.107         3.985         3.565
# 140                           0.070         3.794         3.521
# 141                           0.071         3.762         3.485
# ...

# %% [markdown]
# ##Summary of dataset

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %% [markdown]
# # Observations:
#
#
# 1.   There are a total of 149 entries and all are not-null.
# 2.  There are 18 columns with numeric data and 2 with object type data or categorical data.

# %% [markdown]
# ##Descriptive statistics of world happiness report 2021

# %%
df1.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %% [markdown]
# ##Check for null values in each column

# %%
new_df=df1.isnull()

# This returns a new data frame which has a value false if the value is not null
# else true based on original dataframe
for column in new_df.columns.values:
  print(column , ":" , new_df[column].unique())

# This prints out array of unique values for all columns

print("Clearly none of the columns contain null values")
# Out:
# Country name : [False]
# Regional indicator : [False]
# Ladder score : [False]
# Standard error of ladder score : [False]
# upperwhisker : [False]
# lowerwhisker : [False]
# Logged GDP per capita : [False]
# Social support : [False]
# Healthy life expectancy : [False]
# Freedom to make life choices : [False]
# Generosity : [False]
# Perceptions of corruption : [False]
# Ladder score in Dystopia : [False]
# Explained by: Log GDP per capita : [False]
# Explained by: Social support : [False]
# Explained by: Healthy life expectancy : [False]
# Explained by: Freedom to make life choices : [False]
# Explained by: Generosity : [False]
# Explained by: Perceptions of corruption : [False]
# Dystopia + residual : [False]
# Clearly none of the columns contain null values

# %% [markdown]
# When we checked the summary of dataframe through .info() Then also it was clear that all the columns have not-null entries

# %% [markdown]
# ##Display Unique countries of Western Europe

# %%
unique_countries=df1[df1['Regional indicator']=='Western Europe']['Country name'].unique()

print("Number of unique countries in Western Europe : " , len(unique_countries))

print(unique_countries)
# Out:
# Number of unique countries in Western Europe :  21
# ['Finland' 'Denmark' 'Switzerland' 'Iceland' 'Netherlands' 'Norway'
#  'Sweden' 'Luxembourg' 'Austria' 'Germany' 'Ireland' 'United Kingdom'
#  'Belgium' 'France' 'Malta' 'Spain' 'Italy' 'Cyprus' 'Portugal' 'Greece'
#  'North Cyprus']

# %% [markdown]
# ## World happiness report score for India

# %%
new_df=df1[df1['Country name']=='India']
India_index=new_df.index[0]
print(new_df.loc[India_index , 'Ladder score'])
# Out:
# 3.819

# %% [markdown]
# ## Data of Top 5 east asian countries based on Generosity

# %%
arr=df1[df1['Regional indicator']=='East Asia'].Generosity.sort_values(ascending=False).keys()[:5]
# print(arr)

new_df=df1[df1.index.isin(arr)]

new_df.sort_values(by=['Generosity'] , ascending=False)
# Out:
#                  Country name Regional indicator  Ladder score  \
# 69                   Mongolia          East Asia         5.677
# 76  Hong Kong S.A.R. of China          East Asia         5.477
# 23   Taiwan Province of China          East Asia         6.584
# 61                South Korea          East Asia         5.845
# 83                      China          East Asia         5.339
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 69                           0.042         5.760         5.595
# 76                           0.049         5.573         5.380
# 23                           0.038         6.659         6.510
# 61                           0.042         5.928         5.763
# 83                           0.029         5.397         5.281
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 69                  9.400           0.935                   62.500
# 76                 11.000           0.836                   76.820
# ...

# %% [markdown]
# # **Visualization using Matplotlib Library**

# %% [markdown]
# ##Build a plot (line plot) that shows the variation of 'Ladder score' among the above 5 east asian countries (based on generosity)

# %%
arr=df1[df1['Regional indicator']=='East Asia'].Generosity.sort_values(ascending=False).keys()[:5]
# print(arr)

new_df=df1[df1.index.isin(arr)]
plt.plot(new_df['Generosity'] , new_df['Ladder score'] )
plt.xlabel('Generosity')
plt.ylabel('Ladder score')
plt.title('Ladder score vs Generosity(East Asia)')
plt.grid(True)
plt.show()

# %%
arr=df1[df1['Regional indicator']=='Southeast Asia'].Generosity.sort_values(ascending=False).keys()[:5]
# print(arr)

new_df=df1[df1.index.isin(arr)]
plt.plot(new_df['Generosity'] , new_df['Ladder score'] )
plt.xlabel('Generosity')
plt.ylabel('Ladder score')
plt.title('Ladder score vs Generosity(Southeast Asia)')
plt.grid(True)
plt.show()

# %%
countries=['China', 'Nepal','Bangladesh', 'Pakistan', 'Myanmar', 'India', 'Afghanistan']

new_df =df1[df1['Country name'].isin(countries)]

plt.scatter(new_df['Country name'] , new_df['Logged GDP per capita'] , marker='x' , c='green')

plt.xlabel('Country')
plt.ylabel('Logged GDP per capita')
plt.title('Logged GDP per capita vs Country')
plt.grid(True)
plt.show()
