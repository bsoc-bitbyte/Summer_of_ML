# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !wget https://drive.usercontent.google.com/download?id=1NC9LLMFOqGgfOk3tOCY_Tvk42wPMSjLv&export=download&authuser=0
# Out:
# --2024-06-08 08:40:31--  https://drive.usercontent.google.com/download?id=1NC9LLMFOqGgfOk3tOCY_Tvk42wPMSjLv
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.132.132, 2607:f8b0:4001:c00::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.132.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21687 (21K) [application/octet-stream]
# Saving to: ‘download?id=1NC9LLMFOqGgfOk3tOCY_Tvk42wPMSjLv’
#
# download?id=1NC9LLM 100%[===================>]  21.18K  --.-KB/s    in 0s
#
# 2024-06-08 08:40:32 (113 MB/s) - ‘download?id=1NC9LLMFOqGgfOk3tOCY_Tvk42wPMSjLv’ saved [21687/21687]

# %%
df1 = pd.read_csv("download?id=1NC9LLMFOqGgfOk3tOCY_Tvk42wPMSjLv")

# %%
df1.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
df1.tail(10)
# Out:
#     Country name            Regional indicator  Ladder score  \
# 139      Burundi            Sub-Saharan Africa         3.775
# 140        Yemen  Middle East and North Africa         3.658
# 141     Tanzania            Sub-Saharan Africa         3.623
# 142        Haiti   Latin America and Caribbean         3.615
# 143       Malawi            Sub-Saharan Africa         3.600
# 144      Lesotho            Sub-Saharan Africa         3.512
# 145     Botswana            Sub-Saharan Africa         3.467
# 146       Rwanda            Sub-Saharan Africa         3.415
# 147     Zimbabwe            Sub-Saharan Africa         3.145
# 148  Afghanistan                    South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 139                           0.107         3.985         3.565
# 140                           0.070         3.794         3.521
# 141                           0.071         3.762         3.485
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %%
df1.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
row_nan_count = df1.isnull().any(axis=0)
row_nan_count
# Out:
# Country name                                  False
# Regional indicator                            False
# Ladder score                                  False
# Standard error of ladder score                False
# upperwhisker                                  False
# lowerwhisker                                  False
# Logged GDP per capita                         False
# Social support                                False
# Healthy life expectancy                       False
# Freedom to make life choices                  False
# Generosity                                    False
# Perceptions of corruption                     False
# Ladder score in Dystopia                      False
# Explained by: Log GDP per capita              False
# Explained by: Social support                  False
# Explained by: Healthy life expectancy         False
# Explained by: Freedom to make life choices    False
# Explained by: Generosity                      False
# ...

# %%
df1.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
(df1[df1['Regional indicator'] == "Western Europe"].nunique())[0]
# Out:
# 21

# %%
df1["Regional indicator"].value_counts()
# Out:
# Regional indicator
# Sub-Saharan Africa                    36
# Western Europe                        21
# Latin America and Caribbean           20
# Middle East and North Africa          17
# Central and Eastern Europe            17
# Commonwealth of Independent States    12
# Southeast Asia                         9
# South Asia                             7
# East Asia                              6
# North America and ANZ                  4
# Name: count, dtype: int64

# %%
df1[(df1['Regional indicator'] == "South Asia") & (df1['Country name'] == "India")]
# Out:
#     Country name Regional indicator  Ladder score  \
# 138        India         South Asia         3.819
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 138                           0.026         3.869         3.769
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 138                  8.755           0.603                   60.633
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 138                         0.893       0.089                      0.774
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 138                      2.43                             0.741
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 138                         0.316                                  0.383
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 138                                       0.622                     0.246
#
# ...

# %%
a = (df1[(df1['Regional indicator'] == "East Asia")].sort_values(by="Generosity", ascending=False))[:5]

a.plot(kind="bar", x="Country name", y="Generosity")

plt.title("Top 5 Most Generous Countries in East Asia")
plt.xlabel("Country")
plt.ylabel("Generosity Score")
plt.show()

# %%
a.plot(kind="line", x="Country name", y="Ladder score", color = "red")

plt.title("Ladder score ")
plt.xlabel("country name")
plt.ylabel("ladder score")
plt.show()

# %%
df1[df1["Country name"] == "China"]["Logged GDP per capita"]
# Out:
# 83    9.673
# Name: Logged GDP per capita, dtype: float64

# %%
countries = ['China', 'Nepal', 'Bangladesh', 'Pakistan', 'Myanmar', 'India', 'Afghanistan']
df_2021 = pd.DataFrame({
    'Country': countries,
    'Logged GDP per capita': [9.673, 8.12, 8.454, 8.458, 8.541, 8.755, 7.695]
})

# %%
plt.scatter(df_2021['Country'], df_2021['Logged GDP per capita'])

plt.xlabel('Countries')
plt.ylabel('Logged GDP per capita')
plt.title('Scatter Plot of Countries vs Logged GDP per capita')


plt.show()
