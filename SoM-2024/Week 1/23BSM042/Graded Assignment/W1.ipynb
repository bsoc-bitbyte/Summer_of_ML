# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first graded assignment! Hope that you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We have got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
df = pd.read_csv('/content/W1_Pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
df.shape
# Out:
# (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
df.drop(columns=['#'],inplace=True)

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
df.set_index(df['Name'],inplace=True)

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
#your code here
unique=df['Type 1'].unique()
print(unique)
# Out:
# ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
#your code here
df['New']=df['Type 1'] + '+' + f['Type 2']
filter=df[(df['Type 1']=='Psychic') & (df['Type 2']=='Flying')]
print(filter)
# Out:
#               Name   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# Name
# Natu          Natu  Psychic  Flying    320   40      50       45       70
# Xatu          Xatu  Psychic  Flying    470   65      75       70       95
# Lugia        Lugia  Psychic  Flying    680  106      90      130       90
# Woobat      Woobat  Psychic  Flying    313   55      45       43       55
# Swoobat    Swoobat  Psychic  Flying    425   67      57       55       77
# Sigilyph  Sigilyph  Psychic  Flying    490   72      58       80      103
#
#           Sp. Def  Speed  Generation  Legendary             New
# Name
# Natu           45     70           2      False  Psychic+Flying
# Xatu           70     95           2      False  Psychic+Flying
# Lugia         154    110           2       True  Psychic+Flying
# Woobat         43     72           5      False  Psychic+Flying
# Swoobat        55    114           5      False  Psychic+Flying
# ...

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
#your code here
filter=df['Name'].str.contains('Mega')
result=df[filter]
count=result['Name'].count()
print(count)
# Out:
# 49

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
#your code here
sd=df['Sp. Def'].std()
print(sd)
# Out:
# 27.82891579711746

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
#your code here
count = df['Legendary'].value_counts()
for   value , count in count.items():
    if value==True:
        true_c= count
    else:
        false_c= count
per = ( true_c / (true_c + false_c))  * 100
r_per = round(per, 3)
print(r_per)
# Out:
# 8.125

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
#your code here
filter=df['Defense'].max()
filter2 = df['Name'].where(df['Defense']==filter)
print(filter2.dropna())
# Out:
# Name
# SteelixMega Steelix    SteelixMega Steelix
# Shuckle                            Shuckle
# AggronMega Aggron        AggronMega Aggron
# Name: Name, dtype: object

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
fliter = df[(df['Type 1'] == 'Poison') | (df['Type 2'] == 'Poison')]
fliter.loc[fliter['Attack'].idxmax()]
# Out:
# Name          BeedrillMega Beedrill
# Type 1                          Bug
# Type 2                       Poison
# Total                           495
# HP                               65
# Attack                          150
# Defense                          40
# Sp. Atk                          15
# Sp. Def                          80
# Speed                           145
# Generation                        1
# Legendary                     False
# New                      Bug+Poison
# Name: BeedrillMega Beedrill, dtype: object

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df, hue='Type 1', diag_kind='kde')

# %%
#your code here
g = sns.FacetGrid(df, col="Type 1", col_wrap=4, height=4, )
g.map(sns.histplot, "Attack", bins=20)

# %%
#your code here
corr = df[['HP', 'Attack', 'Defense']].corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
#your code here
filtered_data=df[ ((df['Type 1']=='Ghost')| (df['Type 2'] == 'Ghost'))& (df['Generation']==4) &  (df['Legendary']==False)]
sorted_data = filtered_data.sort_values(by='Speed' , ascending = False)
second_speediest_pokemon = sorted_data.iloc[1]
print(second_speediest_pokemon)
# Out:
# Name          Mismagius
# Type 1            Ghost
# Type 2              NaN
# Total               495
# HP                   60
# Attack               60
# Defense              60
# Sp. Atk             105
# Sp. Def             105
# Speed               105
# Generation            4
# Legendary         False
# New                 NaN
# Name: Mismagius, dtype: object

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
#your code here
chr_attack = df.loc[f['Name'] == 'Charizard' , 'Attack'].values[0]
chr_defense = df.loc[f['Name'] == 'Charizard','Defense'].values[0]

chr_filter = df[(df['Attack']<chr_attack)&(df['Defense']>chr_defense)&(df['Legendary'] == False)]
chr_filter.shape[0]
# Out:
# 116

# %% [markdown]
# ## ***Bonus Questions***
# ## Here are some bonus questions that you can try further !
#
# ### These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
df['T_Attack'] = df['Attack'] + df['Sp. Atk']
df.loc[df['T_Attack'].idxmax()]
# Out:
# Name          RayquazaMega Rayquaza
# Type 1                       Dragon
# Type 2                       Flying
# Total                           780
# HP                              105
# Attack                          180
# Defense                         100
# Sp. Atk                         180
# Sp. Def                         100
# Speed                           115
# Generation                        3
# Legendary                      True
# New                   Dragon+Flying
# T_Attack                        360
# Name: RayquazaMega Rayquaza, dtype: object

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
#your code here
pd.concat([df['Type 1'],df['Type 2']])[df['Legendary']].value_counts().idxmax()
# Out:
# 'Psychic'

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
#your code here
grn_6 = df[(df['Generation'] == 6) & (df['Legendary'] == True)]['HP'].min()
df[(df['Generation'] == 3) & (df['Legendary'] == False) &  (df['HP'] >grn_6)].shape[0]
# Out:
# 95

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here
df.sort_values(by='Speed').iloc[2]
# Out:
# Name            Ferroseed
# Type 1              Grass
# Type 2              Steel
# Total                 305
# HP                     44
# Attack                 50
# Defense                91
# Sp. Atk                24
# Sp. Def                86
# Speed                  10
# Generation              5
# Legendary           False
# New           Grass+Steel
# T_Attack               74
# Name: Ferroseed, dtype: object

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
conc = pd.concat([df['Type 1'], df['Type 2']] , ignore_index = True)
hp_ = pd.concat([df['HP'], df['HP']] , ignore_index = True)
hp_df = pd.DataFrame({'Type': conc, 'HP': hp_})
hp_df.groupby('Type')['HP'].mean().idxmax()
# Out:
# 'Dragon'
