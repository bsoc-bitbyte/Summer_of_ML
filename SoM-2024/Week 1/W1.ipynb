# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# # **Gotta catch 'em all !**

# %% [markdown]
# ![download.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Welcome to your first graded assignment! Hope that you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about Pokemons.**
#
# **We have got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df=pd.read_csv("W1_Pokemon.csv")
print(df)
# Out:
#       u#                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (800, 13)

# %%
#your code here
print("Shape of dataframe:",df.shape)
# Out:
# Shape of dataframe: (800, 13)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
print("Columns of dataframe:",df.columns.tolist())
# Out:
# Columns of dataframe: ['u#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']

# %% [markdown]
# ### 5) Remove the column '#' and update the dataframe.

# %%
#your code here
df.drop(df.columns[0],axis=1,inplace=True)
print("updated dataframe after removing '#' is:")
print(df)
# Out:
# updated dataframe after removing '#' is:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### 6) Set the 'Name' column as the index of dataframe

# %%
#your code here
df.set_index("Name",inplace=True)

# %% [markdown]
# ###  7) Print a list of all the unique Type-1 powers

# %%
#your code here
unq_typ=df["Type 1"].unique()
print("Unique Type 1 powers:",unq_typ)
# Out:
# Unique Type 1 powers: ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying']

# %% [markdown]
# ### 8) Create a column which contains the Type 1 and Type 2 abilities of pokemons, seperated with a '+'' sign. Also, display the no. of pokemons that have type-1 power as 'Psychic' and type 2 power as 'Flying' using this new column.

# %%
#your code here

#Formming a new column Type 3 with value Type1 + Type2
df["Type 3"] = df["Type 1"] + "+" + df["Type 2"]

df["Type 3"].value_counts()["Psychic+Flying"]
# Out:
# 6

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. How many pokemons have 'Mega' in their name?

# %%
#your code here
mega_pokemon=df[df.index.str.contains('Mega')].shape[0]
print("No. of pokemons with mega in their name:",mega_pokemon)
# Out:
# No. of pokemons with mega in their name: 49

# %% [markdown]
# ### 2. What is the standard deviation of Sp. Def. in the dataset ?

# %%
#your code here
#Evaluate mean of Sp. Def
mean = df["Sp. Def"].mean()

#Initialise sum with value 0
sum = 0;

for value in df["Sp. Def"]:

  #Calculate mean
  sum = sum + (value - mean) ** 2

#standardDeviation 
standardDeviation = (sum / 800) ** (1/2)
standardDeviation
# Out:
# 27.811517286009394

# %% [markdown]
# ### 3. What percentage (upto 3 decimal places) of pokemons are legendary ?

# %%
#your code here
legend_percentage=(df["Legendary"].mean())*100
print("Percentage of pokemons that are legendary",legend_percentage)
# Out:
# Percentage of pokemons that are legendary 8.125

# %% [markdown]
# ### 4. Name the pokemon(s) with Maximum Defense.

# %%
#your code here
max_defense=df['Defense'].max()
print(max_defense)
# Out:
# 230

# %% [markdown]
# ### 5. Which poison pokemon has the strongest attack ?

# %%
#your code here
strong_poison=df[df["Type 1"]=="Poison"]["Attack"]
print("Pokemon with strongest poison attack:",strong_poison)
# Out:
# Pokemon with strongest poison attack: Name
# Ekans         60
# Arbok         85
# Nidoran♀      47
# Nidorina      62
# Nidoqueen     92
# Nidoran♂      57
# Nidorino      72
# Nidoking     102
# Zubat         45
# Golbat        80
# Grimer        80
# Muk          105
# Koffing       65
# Weezing       90
# Crobat        90
# Gulpin        43
# Swalot        73
# Seviper      100
# Stunky        63
# Skuntank      93
# Skorupi       50
# Drapion       90
# Croagunk      61
# Toxicroak    106
# Trubbish      50
# Garbodor      95
# Skrelp        60
# Dragalge      75
# Name: Attack, dtype: int64

# %% [markdown]
# ### 6. Using seaborn make different types of plots, observe the trend and answer the questions given in the form.

# %%
#your code here
plt.figure(figsize=(10,6))
sns.histplot(df["Attack"],bins=20,kde=True)
plt.title("Distribution of attack")
plt.xlabel("Attack")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\nafis\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#your code here
plt.figure(figsize=(10,6))
sns.scatterplot(data=df,x="Attack",y="Defense",hue="Legendary")
plt.title("Scatter plot between attack and defense")
plt.xlabel("Attack")
plt.ylabel("Defense")
plt.show()

# %%
#your code here
plt.figure(figsize=(10,6))
sns.countplot(data=df,x="Generation",palette="viridis")
plt.title("Distribution of pokemons across generation")
plt.xlabel("Generation")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### 7. Which is the second fastest non-legendary 'Ghost' type pokemon from 4th generation ?

# %%
#your code here
#Forming a variable to satisfy all the conditions
conditions1 = ((df["Type 1"] == "Ghost") | (df["Type 2"] == "Ghost")) & (df["Legendary"] == False) & (df["Generation"] == 4)

#Filter the dataSet satisfying the conditions
newDataSet1 = df[conditions1]

#Acquire index of the row having maximum Speed
index = newDataSet1[newDataSet1["Speed"] == newDataSet1.Speed.max()].index

#Delete the row having maximum value
newDataSet = newDataSet1.drop(index)

#Now the maximum Speed is the second fastest Non-legendary 'Ghost' type pokemon from 4th generation
newDataSet.Speed.max()
# Out:
# 105

# %% [markdown]
# ### 8. How many non-legendary pokemons have stronger defence but weaker attack than Charizard?

# %%
#your code here
charizard_defense=df.loc['Charizard']['Defense']
charizard_attack=df.loc['Charizard']['Attack']
strng_def=df[(df['Legendary']==False)&(df['Defense']>charizard_defense)&(df['Attack']<charizard_attack)].shape[0]
print("Number of non-legendary pokemons that have stronger defense but weaker attack than charizard:",strng_def)
# Out:
# Number of non-legendary pokemons that have stronger defense but weaker attack than charizard: 116

# %% [markdown]
# ## ***Bonus Questions***
# ## Here are some bonus questions that you can try further !
#
# ### These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Which pokemon has the highest combined value of Attack and Sp. Atk ?

# %%
#your code here

# %% [markdown]
# ### Which type of legendary pokemons are the most common?

# %%
#your code here

# %% [markdown]
# ### How many generation-3, non-legendary pokemons have higher HP than the weakest generation-6, legendary pokemon?

# %%
#your code here

# %% [markdown]
# ### Print out the third slowest pokemon(s) in the dataset.

# %%
#your code here

# %% [markdown]
# ### Which pokemon type has the highest average HP?

# %%
#your code here
