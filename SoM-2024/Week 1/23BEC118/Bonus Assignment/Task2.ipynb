# %%
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv(r'C:\Users\Shruti Sachan\Downloads\world-happiness-report-2021.csv')
df1.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
df3=df1.sort_values(by='Generosity',ascending=False)
df4=df3.head(5)
# Out:
#     Country name                  Regional indicator  Ladder score  \
# 81     Indonesia                      Southeast Asia         5.345
# 125      Myanmar                      Southeast Asia         4.426
# 97        Gambia                  Sub-Saharan Africa         5.051
# 142        Haiti         Latin America and Caribbean         3.615
# 41    Uzbekistan  Commonwealth of Independent States         6.179
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 81                            0.056         5.454         5.235
# 125                           0.052         4.527         4.324
# 97                            0.089         5.225         4.877
# 142                           0.173         3.953         3.276
# 41                            0.068         6.312         6.045
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 81                   9.365           0.811                   62.236
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df3=df1.sort_values(by='Generosity',ascending=False)
df4=df3.head(5)
plt.plot(df4['Country name'],df4['Ladder score'])
plt.title('variation of ladder Score on the basis of Generosity')
plt.xlabel('Top 5 Countries')
plt.ylabel('Ladder Scores')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
country=['China','Nepal','Bangladesh','Pakistan','Myanmar','India','Afghanistan']
df_2021=df1[df1['Country name'].isin(country)]
plt.title('Relation between Countries vs Logged GDP per capita')
plt.xlabel('countries')
plt.ylabel('Logged GDP per capita')
plt.scatter(df_2021['Country name'],df_2021['Logged GDP per capita'])
